# %%
import pandas as pd

# %%
book = pd.read_csv('book_embedded.csv', encoding='cp949', names=[0, 1, 'embedding'])
book = book.dropna()
book
# Out:
#                       0                                                  1  \
# 0          나라면 나와 결혼할까?  ['저자', '풍부하다', '경험', '감성', '글', '사랑', '이', '이야...
# 1     기분을 관리하면 인생이 관리된다  ['자신', '솔직하다', '원하다', '때', '나', '어떻다', '사람', '...
# 2              당신이라는 기적  ['조금', '서투르다', '충분하다', '그', '깊다', '위로', '속', '...
# 3    나는 당신이 행복했으면 좋겠습니다  ['나', '당신', '행복하다', '좋다', '저자', '삶', '속', '사랑'...
# 4    당신은 결국 무엇이든 해내는 사람  ['내', '장례식', '누가', '를', '통해', '수많다', '독자', '사랑...
# ..                  ...                                                ...
# 574                 브라질  ['전설', '챔피언', '복서', '무하마드', '알리', '조지', '포', '...
# 575          장국영이 죽었다고?  ['현대문학', '추천', '등단', '하종오', '시집', '사랑', '부재', ...
# 576       바람과 함께 사라지다 상  ['구운몽', '당태종', '전', '숙향전', '등', '경판', '방각', '소...
# 577              노인과 바다  ['사회', '구비문학', '연구', '책', '한국', '구비문학', '회', '...
# 578                가곡원류  ['우리', '읽다', '하다', '고전', '시리즈', '중', '하나로', '춘...
#
#                                              embedding
# ...

# %%
book.to_csv('bookdata_final.csv', encoding='utf-8-sig', index=False)

# %%
book = pd.read_csv('bookdata_final.csv')
book
# Out:
#                       0                                                  1  \
# 0          나라면 나와 결혼할까?  ['저자', '풍부하다', '경험', '감성', '글', '사랑', '이', '이야...
# 1     기분을 관리하면 인생이 관리된다  ['자신', '솔직하다', '원하다', '때', '나', '어떻다', '사람', '...
# 2              당신이라는 기적  ['조금', '서투르다', '충분하다', '그', '깊다', '위로', '속', '...
# 3    나는 당신이 행복했으면 좋겠습니다  ['나', '당신', '행복하다', '좋다', '저자', '삶', '속', '사랑'...
# 4    당신은 결국 무엇이든 해내는 사람  ['내', '장례식', '누가', '를', '통해', '수많다', '독자', '사랑...
# ..                  ...                                                ...
# 574                 브라질  ['전설', '챔피언', '복서', '무하마드', '알리', '조지', '포', '...
# 575          장국영이 죽었다고?  ['현대문학', '추천', '등단', '하종오', '시집', '사랑', '부재', ...
# 576       바람과 함께 사라지다 상  ['구운몽', '당태종', '전', '숙향전', '등', '경판', '방각', '소...
# 577              노인과 바다  ['사회', '구비문학', '연구', '책', '한국', '구비문학', '회', '...
# 578                가곡원류  ['우리', '읽다', '하다', '고전', '시리즈', '중', '하나로', '춘...
#
#                                              embedding
# ...

# %%
movie = pd.read_csv('movie_final.csv', encoding='cp949', names=[0, 1, 'embedding'])
movie = movie[movie['embedding']!='embedding']
movie = movie.dropna()
movie
# Out:
#                           0  \
# 0               MIX & MATCH
# 1             美親 유럽 - 예뻐질지도
# 2                  로맨스의 일주일
# 3        추석특집 2014 퀴즈 온 코리아
# 4      추석특집 백년해로 - 참 고마운 당신
# ...                     ...
# 28087                 에듀케이션
# 28088          나의 끝, 당신의 시작
# 28089         천재 화가 고야 특급살인
# 28090               어쩌다 아스널
# 28091                   어게인
#
#                                                        1  \
# 0      ['WIN', 'B', '팀', '멤버', '치열하다', '오디션', '경쟁', '...
# 1      ['예쁘다', '지도', '따라가다', '2', '주간', '미치다', '유럽', ...
# 2      ['화려하다', '스포트라이트', '뒤', '숨기다', '그녀', '진솔', '되다...
# 3      ['외국인', '한국', '대한', '관심', '높이', '한국', '국제', '적...
# 4      ['일', '년', '중', '달이', '가장', '밝다', '추석', '환하다',...
# ...                                                  ...
# 28087  ['손', '보지', '제', '인생', '무게', '기도', '힘드다', '우리'...
# 28088  ['우연', '운명', '행복하다', '시간', '연인', '엄청나다', '불행',...
# 28089  ['화가', '곱다', '그림', '모방', '연쇄살인', '사건', '범인', '...
# ...

# %%
movie.to_csv('movie_final_data.csv', encoding='utf-8-sig', index=False)

# %%
movie = pd.read_csv('movie_final_data.csv')
movie
# Out:
#                           0  \
# 0               MIX & MATCH
# 1             美親 유럽 - 예뻐질지도
# 2                  로맨스의 일주일
# 3        추석특집 2014 퀴즈 온 코리아
# 4      추석특집 백년해로 - 참 고마운 당신
# ...                     ...
# 28086                 에듀케이션
# 28087          나의 끝, 당신의 시작
# 28088         천재 화가 고야 특급살인
# 28089               어쩌다 아스널
# 28090                   어게인
#
#                                                        1  \
# 0      ['WIN', 'B', '팀', '멤버', '치열하다', '오디션', '경쟁', '...
# 1      ['예쁘다', '지도', '따라가다', '2', '주간', '미치다', '유럽', ...
# 2      ['화려하다', '스포트라이트', '뒤', '숨기다', '그녀', '진솔', '되다...
# 3      ['외국인', '한국', '대한', '관심', '높이', '한국', '국제', '적...
# 4      ['일', '년', '중', '달이', '가장', '밝다', '추석', '환하다',...
# ...                                                  ...
# 28086  ['손', '보지', '제', '인생', '무게', '기도', '힘드다', '우리'...
# 28087  ['우연', '운명', '행복하다', '시간', '연인', '엄청나다', '불행',...
# 28088  ['화가', '곱다', '그림', '모방', '연쇄살인', '사건', '범인', '...
# ...
