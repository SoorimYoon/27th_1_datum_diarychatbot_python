# %%
pip install sentence_transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
model = SentenceTransformer('jhgan/ko-sroberta-multitask')

# %%
from tqdm import tqdm
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/Shareddrives/솔룩스 데이텀/naverbook_konlpy.csv', header=None)
df
# Out:
#                         0                                                  1
# 0    사랑하라 한번도 상처받지 않은 것처럼  ['그대', '곁', '있다', '나', '그대', '그리다', '외눈박이', '물...
# 1             내 아버지로부터의 꿈  ['따뜻하다', '휴머니즘', '빛나다', '지성', '부드럽다', '카리스마', ...
# 2              이 짧은 시간 동안  ['눈물', '나다', '기차', '타라', '이후', '펴내다', '정호승', '...
# 3          헬렌 니어링의 소박한 밥상  ['스', '코트', '니', '링', '아내', '이자', '미국', '유명하다'...
# 4                사랑하는 아빠가  ['새벽같이', '나가다', '밤', '손님', '돌아오다', '아빠', '아침',...
# ..                    ...                                                ...
# 126                   브라질  ['전설', '챔피언', '복서', '무하마드', '알리', '조지', '포', '...
# 127            장국영이 죽었다고?  ['현대문학', '추천', '등단', '하종오', '시집', '사랑', '부재', ...
# 128         바람과 함께 사라지다 상  ['구운몽', '당태종', '전', '숙향전', '등', '경판', '방각', '소...
# 129                노인과 바다  ['사회', '구비문학', '연구', '책', '한국', '구비문학', '회', '...
# 130                  가곡원류  ['우리', '읽다', '하다', '고전', '시리즈', '중', '하나로', '춘...
#
# [131 rows x 2 columns]

# %%
#인코딩 
df['embedding']=pd.Series([[]]*len(df))
df['embedding']= df[1].map(lambda x: list(model.encode(x)))
df.head()
# Out:
#                       0                                                  1  \
# 0  사랑하라 한번도 상처받지 않은 것처럼  ['그대', '곁', '있다', '나', '그대', '그리다', '외눈박이', '물...
# 1           내 아버지로부터의 꿈  ['따뜻하다', '휴머니즘', '빛나다', '지성', '부드럽다', '카리스마', ...
# 2            이 짧은 시간 동안  ['눈물', '나다', '기차', '타라', '이후', '펴내다', '정호승', '...
# 3        헬렌 니어링의 소박한 밥상  ['스', '코트', '니', '링', '아내', '이자', '미국', '유명하다'...
# 4              사랑하는 아빠가  ['새벽같이', '나가다', '밤', '손님', '돌아오다', '아빠', '아침',...
#
#                                            embedding
# 0  [0.6138155, -0.6115886, 0.014525136, 0.0030739...
# 1  [0.31358317, 0.07098198, -0.05547391, -0.52628...
# 2  [0.4532722, -0.34439313, -0.17896721, -0.19552...
# 3  [0.17487302, -0.19338112, -0.14265482, -0.3859...
# 4  [0.2783903, -0.28351542, -0.20894738, -0.23900...

# %%
#embedding 값을 포함하여 새로운 csv로 저장


df.to_csv("naverbook_embedded.csv", encoding='utf-8-sig', index=False, header = False) 
from google.colab import files
files.download("naverbook_embedded.csv")

# %%
ds = pd.read_csv('/content/drive/Shareddrives/솔룩스 데이텀/book_embedded.csv', encoding='cp949',header = None)
ds
# Out:
#                       0                                                  1  \
# 0          나라면 나와 결혼할까?  ['저자', '풍부하다', '경험', '감성', '글', '사랑', '이', '이야...
# 1     기분을 관리하면 인생이 관리된다  ['자신', '솔직하다', '원하다', '때', '나', '어떻다', '사람', '...
# 2              당신이라는 기적  ['조금', '서투르다', '충분하다', '그', '깊다', '위로', '속', '...
# 3    나는 당신이 행복했으면 좋겠습니다  ['나', '당신', '행복하다', '좋다', '저자', '삶', '속', '사랑'...
# 4    당신은 결국 무엇이든 해내는 사람  ['내', '장례식', '누가', '를', '통해', '수많다', '독자', '사랑...
# ..                  ...                                                ...
# 576       바람과 함께 사라지다 상  ['구운몽', '당태종', '전', '숙향전', '등', '경판', '방각', '소...
# 577              노인과 바다  ['사회', '구비문학', '연구', '책', '한국', '구비문학', '회', '...
# 578                가곡원류  ['우리', '읽다', '하다', '고전', '시리즈', '중', '하나로', '춘...
# 579                                                                   NaN
# 580                 NaN                                                NaN
#
#                                                      2
# ...

# %%
ds= ds.dropna(axis=0)

# %%
ds
# Out:
#                       0                                                  1  \
# 0          나라면 나와 결혼할까?  ['저자', '풍부하다', '경험', '감성', '글', '사랑', '이', '이야...
# 1     기분을 관리하면 인생이 관리된다  ['자신', '솔직하다', '원하다', '때', '나', '어떻다', '사람', '...
# 2              당신이라는 기적  ['조금', '서투르다', '충분하다', '그', '깊다', '위로', '속', '...
# 3    나는 당신이 행복했으면 좋겠습니다  ['나', '당신', '행복하다', '좋다', '저자', '삶', '속', '사랑'...
# 4    당신은 결국 무엇이든 해내는 사람  ['내', '장례식', '누가', '를', '통해', '수많다', '독자', '사랑...
# ..                  ...                                                ...
# 574                 브라질  ['전설', '챔피언', '복서', '무하마드', '알리', '조지', '포', '...
# 575          장국영이 죽었다고?  ['현대문학', '추천', '등단', '하종오', '시집', '사랑', '부재', ...
# 576       바람과 함께 사라지다 상  ['구운몽', '당태종', '전', '숙향전', '등', '경판', '방각', '소...
# 577              노인과 바다  ['사회', '구비문학', '연구', '책', '한국', '구비문학', '회', '...
# 578                가곡원류  ['우리', '읽다', '하다', '고전', '시리즈', '중', '하나로', '춘...
#
#                                                      2
# ...

# %%
ds.to_csv("book_final.csv", encoding='utf-8-sig', index=False, header = False) 
from google.colab import files
files.download("book_final.csv")
