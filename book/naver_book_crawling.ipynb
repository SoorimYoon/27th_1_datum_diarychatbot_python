# %% [markdown]
# ### 시 에세이

# %%
import requests
import re 
from bs4 import BeautifulSoup

criticism_list=[]

for i in range(1,51):
    url = "https://book.naver.com/category/index.naver?cate_code=110&tab=recommend&list_type=list&sort_type=salecount&page={}".format(i)
    res = requests.get(url)
    res.raise_for_status()
    soup = BeautifulSoup(res.text, "lxml") #우리가 가져온 html 문서를 -> 뷰티풀숲 객체로 만든다.

    books = soup.find_all("a", attrs={"class":"N=a:bta.title"})
    
    for book in books:
        book_url = book["href"]
        try:
            book_res=requests.get(book_url)
            book_res.raise_for_status()

            soup2 = BeautifulSoup(book_res.text, "lxml")

            criticism = soup2.find("li", attrs={"class":"d_tab2"})
            if criticism:
                criticism_url = 'https://book.naver.com' + str(criticism.a['href'])
                criticism_res = requests.get(criticism_url)
                criticism_res.raise_for_status()

                soup3 = BeautifulSoup(criticism_res.text, "lxml")

                pcriticism = soup3.find("div", attrs={"id":"pubReviewContent"})
                review = pcriticism.p.get_text()
                #print(f"출판사서평: {review}")
                criticism_list.append(review)
                #print()
            else:
                personreview = soup2.find("div", attrs={"id":"bookIntroContent"})
                if personreview:
                    ppreview = personreview.get_text()
                    #print(f"책소개: {ppreview}")
                    criticism_list.append(ppreview)
                    #print()
                else:
                    #print("서평없음")
                    criticism_list.append("X")
        except:
            continue

# %%
title_list=[]

for i in range(1,51):
    url = "https://book.naver.com/category/index.naver?cate_code=110&tab=recommend&list_type=list&sort_type=salecount&page={}".format(i)
    res = requests.get(url)
    res.raise_for_status()
    soup = BeautifulSoup(res.text, "lxml") #우리가 가져온 html 문서를 -> 뷰티풀숲 객체로 만든다.

    books = soup.find_all("a", attrs={"class":"N=a:bta.title"})

    for book in books:
        title = book.get_text()
        #print(title)
        title_list.append(title)

# %% [markdown]
# ### 자기계발

# %%
for i in range(1,12):
    url = "https://book.naver.com/category/index.naver?cate_code=170&tab=recommend&list_type=list&sort_type=salecount&page={}".format(i)
    res = requests.get(url)
    res.raise_for_status()
    soup = BeautifulSoup(res.text, "lxml") #우리가 가져온 html 문서를 -> 뷰티풀숲 객체로 만든다.

    books = soup.find_all("a", attrs={"class":"N=a:bta.title"})
    
    for book in books:
        book_url = book["href"]
        try:
            book_res=requests.get(book_url)
            book_res.raise_for_status()

            soup2 = BeautifulSoup(book_res.text, "lxml")

            criticism = soup2.find("li", attrs={"class":"d_tab2"})
            if criticism:
                criticism_url = 'https://book.naver.com' + str(criticism.a['href'])
                criticism_res = requests.get(criticism_url)
                criticism_res.raise_for_status()

                soup3 = BeautifulSoup(criticism_res.text, "lxml")

                pcriticism = soup3.find("div", attrs={"id":"pubReviewContent"})
                review = pcriticism.p.get_text()
                #print(f"출판사서평: {review}")
                criticism_list.append(review)
                #print()
            else:
                personreview = soup2.find("div", attrs={"id":"bookIntroContent"})
                if personreview:
                    ppreview = personreview.get_text()
                    #print(f"책소개: {ppreview}")
                    criticism_list.append(ppreview)
                    #print()
                else:
                    #print("서평없음")
                    criticism_list.append("X")
        except:
            continue

# %%
for i in range(1,12):
    url = "https://book.naver.com/category/index.naver?cate_code=170&tab=recommend&list_type=list&sort_type=salecount&page={}".format(i)
    res = requests.get(url)
    res.raise_for_status()
    soup = BeautifulSoup(res.text, "lxml") #우리가 가져온 html 문서를 -> 뷰티풀숲 객체로 만든다.

    books = soup.find_all("a", attrs={"class":"N=a:bta.title"})

    for book in books:
        title = book.get_text()
        #print(title)
        title_list.append(title)

# %% [markdown]
# ### 인문

# %%
for i in range(1,99):
    url = "https://book.naver.com/category/index.naver?cate_code=120&tab=recommend&list_type=list&sort_type=salecount&page={}".format(i)
    res = requests.get(url)
    res.raise_for_status()
    soup = BeautifulSoup(res.text, "lxml") #우리가 가져온 html 문서를 -> 뷰티풀숲 객체로 만든다.

    books = soup.find_all("a", attrs={"class":"N=a:bta.title"})
    
    for book in books:
        book_url = book["href"]
        try:
            book_res=requests.get(book_url)
            book_res.raise_for_status()

            soup2 = BeautifulSoup(book_res.text, "lxml")

            criticism = soup2.find("li", attrs={"class":"d_tab2"})

            if criticism:
                criticism_url = 'https://book.naver.com' + str(criticism.a['href'])
                criticism_res = requests.get(criticism_url)
                criticism_res.raise_for_status()

                soup3 = BeautifulSoup(criticism_res.text, "lxml")

                pcriticism = soup3.find("div", attrs={"id":"pubReviewContent"})
                review = pcriticism.p.get_text()
                #print(f"출판사서평: {review}")
                criticism_list.append(review)
                #print()
            else:
                personreview = soup2.find("div", attrs={"id":"bookIntroContent"})
                if personreview:
                    ppreview = personreview.get_text()
                    #print(f"책소개: {ppreview}")
                    criticism_list.append(ppreview)
                    #print()
                else:
                    #print("서평없음")
                    criticism_list.append("X")
        except:
            continue

# %%
for i in range(1,99):
    url = "https://book.naver.com/category/index.naver?cate_code=120&tab=recommend&list_type=list&sort_type=salecount&page={}".format(i)
    res = requests.get(url)
    res.raise_for_status()
    soup = BeautifulSoup(res.text, "lxml") #우리가 가져온 html 문서를 -> 뷰티풀숲 객체로 만든다.

    books = soup.find_all("a", attrs={"class":"N=a:bta.title"})

    for book in books:
        title = book.get_text()
        print(title)
        title_list.append(title)
# Out:
# 욕망의 진화
# 예루살렘의 아이히만
# 생각의 탄생
# 생각의 지도
# 스키너의 심리상자 열기
# 행복의 정복
# 만들어진 신
# 타인의 고통
# 강의
# 일리아스
# 게으름에 대한 찬양
# 명상록
# 책만 보는 바보
# 변신이야기 1
# 문장강화
# 도덕경
# 철학카페에서 문학 읽기
# 시나리오 어떻게 쓸 것인가 1
# 고맙다 논리야
# 플라톤의 국가·정체
# 통섭
# 은유로서의 질병
# 기술복제시대의 예술작품 사진의 작은 역사 외
# 격몽요결
# 행복에 걸려 비틀거리다
# 소설처럼
# 빈 서판
# 슬픈 열대
# 글쓰기의 전략
# 문학의 숲을 거닐다
# 안정효의 글쓰기 만보
# 아이스퀼로스 비극 전집
# 정신분석적 사례이해
# 벤야민 & 아도르노
# 쿤&포퍼
# 서재 결혼 시키기
# 노자이야기
# 논리-철학 논고
# 낭만적 거짓과 소설적 진실
# 자크 라캉 세미나 11
# 프로테스탄티즘의 윤리와 자본주의 정신
# 종교적 경험의 다양성
# 당신의 그림자가 울고 있다
# 종교의 기원
# 제국의 시대
# 푸코 & 하버마스
# 놀이와 예술 그리고 상상력
# 철학과 굴뚝청소부
# 일방통행로 사유이미지
# 공산당선언
# 창조적 진화
# 시간과 타자
# 시와 함께 배우는 시론
# 열정과 기질
# 야생의 사고
# 산해경
# 사기열전 2
# 한국현대문학사 1
# 신화, 인류 최고의 철학
# 키케로의 의무론
# 나를 바꾸는 글쓰기 공작소
# 공간의 시학
# 에밀
# 청소년을 위한 서양철학사
# 희망의 인문학
# 자아 놀이 공원
# 내러티브 탐구
# 비극의 탄생.반시대적 고찰
# 옛이야기의 매력 1
# 미의 역사
# 에우티프론, 소크라테스의 변론, 크리톤, 파이돈
# 나는 사탄이 번개처럼 떨어지는 것을 본다
# 추의 역사
# 북학의
# 이윤기의 그리스 로마 신화 4
# 의지와 표상으로서의 세계
# 철학, 영화를 캐스팅하다
# 정신 요법의 기본 문제
# 의사소통행위이론 1
# 마음의 진보
# 채근담
# 증여론
# 삶으로서의 은유
# 물질과 기억
# 외국어로서의 한국어 발음교육론
# 헤겔 정신현상학의 이해
# 지식의 통섭
# 노자와 21세기 1
# 자본의 시대
# 노마디즘 1
# 삶의 의미를 찾아서
# 나무열전
# 연애
# 느끼는 뇌
# 신화적 상상력과 문화
# 이집트 사자의 서
# 선비답게 산다는 것
# 그리스 비극에 대한 편지
# 짐멜의 모더니티 읽기
# 미국의 민주주의 1
# 수업, 비평의 눈으로 읽다
# 논어
# 문화의 패턴
# 플라톤의 티마이오스
# 열하일기 세트
# 발터 벤야민과 아케이드 프로젝트
# 철학 삶을 만나다
# 28자로 이룬 문자혁명 훈민정음
# 츠바이크의 발자크 평전
# 철학 콘서트 1
# 자유론
# 우리말의 수수께끼
# 슬럼, 지구를 뒤덮다
# 근대문학의 종언
# 위험한 생각들
# 놀이의 달인, 호모 루덴스
# 한글에 대해 알아야 할 모든 것
# 최초의 신화 길가메쉬 서사시
# 왕필의 노자주
# 세계종교사상사 1
# 여성시대에는 남자도 화장을 한다
# 소크라테스에서 포스트모더니즘까지
# 현산어보를 찾아서 1
# 불안
# 연암을 읽는다
# 이상대의 4050 학급살림 이야기
# 과학철학의 이해
# 우리속에 있는 지혜의 여신들
# 나이 들수록 왜 시간은 빨리 흐르는가
# 아웃사이더
# 종교전쟁
# 신경림의 시인을 찾아서 1
# 미학이론
# 한글세대가 본 논어 1
# 기초한문독해법
# 에밀
# 건투를 빈다
# 오리엔탈리즘
# 동일성과 차이
# 혁명의 시대
# 관계의 재구성
# 한자의 뿌리 1
# 아이들이 꿈꾸는 학교
# 신의 가면 2
# 불멸의 작가, 위대한 상상력
# 서경강설
# 영미문학의 길잡이 1
# 사기열전 상
# 읽기의 힘, 듣기의 힘
# 블링크
# 자존심
# 분서 1
# 열하일기 웃음과 역설의 유쾌한 시공간
# 오제은 교수의 자기사랑노트
# 차이와 타자
# 세계 그림책의 역사
# 그리스 비극의 이해
# 실용주의
# 몽상의 시학
# 위기개입
# 감시와 처벌
# 죽음의 수용소에서
# 두글자의 철학
# 철학, 역사를 만나다
# 논어의 문법적 이해
# 들뢰즈 철학과 영화
# 18세기 조선 지식인의 발견
# 아내를 모자로 착각한 남자
# 회남자
# 강수돌 교수의 '나부터' 교육혁명
# 촘스키, 누가 무엇으로 세상을 지배하는가
# 호모 코레아니쿠스
# 지식인의 책무
# 분서 2
# 석도화론
# 간디, 나의 교육철학
# 인지발달
# 라깡의 재탄생
# 아직도 가야 할 길
# 우연과 필연
# 장정일의 공부
# 문화의 수수께끼
# 신화의 힘
# 자유주의적 평등
# 영화 인문학
# 고대문명교류사
# 미학 오디세이 1
# 다산 정약용
# 근사록집해 1
# 딥스
# 이미지
# 독서
# 한자의 뿌리 2
# 역사왜곡과 우리의 역사교육
# 청소년 문제행동
# 공자
# 조선유학의 [개념]들
# 대담
# 인지과학
# 니체, 프로이트, 맑스 이후
# 러시아정교
# 삼국유사
# 문심조룡
# 세계가 높이 산 한국의 문기
# 우리가 정말 알아야 할 우리 신화
# 뿌리 깊은 나무의 생각
# 발달심리학 거장들의 핵심이론 연구
# 미학 오디세이 3
# 한국의 교양을 읽는다 2
# 한시의세계
# 시간의 철학적 성찰
# 곰에서 왕으로
# 근대의 서사시
# 신경림의 시인을 찾아서 2
# 청소년을 위한 한국철학사
# 특집! 한창기
# 전쟁과 평화 1
# 살아있는 우리신화
# 얘들아, 너희가 나쁜 게 아니야
# 군주론
# 밤으로의 여행
# 마이클 더다의 고전 읽기의 즐거움
# 유쾌한 심리학 1
# 루시퍼 이펙트
# 세계 최고의 여행기 열하일기 상
# 독기학설
# 통찰과 포용
# 중국현대사상사론
# 인간의 조건
# 유교와 한국문학의 장르
# 미학 오디세이 2
# 타타르키비츠 미학사 1
# 사회심리학
# 유경의 죽음 준비학교
# 바보 만들기
# 문화상징사전
# 제인 구달 & 루이스 리키
# 모던 타임스 1
# 만족
# 책문 시대의 물음에 답하라
# 세계 최고의 여행기 열하일기 하
# 잡식동물의 딜레마
# 결정적 논고
# 또 다른 예수
# 지식의 발견
# 건축에게 시대를 묻다
# 지식의 대융합
# 춘아 춘아 옥단춘아 네 아버지 어디 갔니
# 4천만의 국어책
# 조선의 마지막 문장
# 나는 기생이다
# 마추픽추 정상에서 라틴아메리카를 보다
# 건방진 우리말 달인
# 나는 대한민국의 교사다
# 손녀딸 릴리에게 주는 편지
# 한국 도교의 기원과 역사
# 주제와 변주 1
# 한국의 글쟁이들
# 미학이란 무엇인가
# 행복한 책 읽기
# 21세기 아침의 사색
# 우리가 아는 세계의 종언
# 공산당 선언
# 생성의 철학
# How to be happy
# 고문진보 전집
# 철학, 도시를 디자인하다 1
# 이육사전집
# 근대적 주거공간의 탄생
# 국어의미론
# 긍정 심리학
# 국어 교육의 이해
# 김학철 평전
# 육체와 예술
# 당신은 이미 소설을 쓰기 시작했다
# 한국어 화용론
# 생활의 발견
# 진단명 사이코패스
# 니체, 생명과 치유의 철학
# 중국현대문학과의 만남
# 노래하는 강아지똥
# 세계종교 둘러보기
# 이야기 동양 신화 1
# 나의 레종 데트르
# 노신 평전
# 침묵의 세계
# 발터 벤야민의 문예이론
# 한국소설묘사사전 1
# 한시미학산책
# 퇴계 달중이를 만나다
# 철학의 개념과 주요문제
# 윤리 21
# 인물로 읽는 장자
# 이분법을 넘어서
# 정지용 시 126편 다시 읽기
# 세계문학사의 전개
# 지식의 최전선
# 동양의 고전을 읽는다 2
# 아주 특별한 책들의 이력서
# 우리가 성에 관해 너무나 몰랐던 일들
# 영화속의 철학
# 역사학의 철학
# 빈 방에 달빛 들면
# 죽음앞에 선 인간 상
# 종교근본주의와 종교분쟁
# 릴케와 한국의 시인들
# 두보 평전
# 영화관 옆 철학카페
# 이우학교 이야기
# 놀이 마르지 않는 창조의 샘
# 헝그리 플래닛
# 동양과 서양, 그리고 미학
# 인간과 상징
# 풍류
# 유쾌한 기억의 심리학
# 대승기신론 통석
# 의미 만들기의 미술
# 고사성어 문화답사기 1
# 사라진 신들과의 교신을 위하여
# 상징 이야기
# 페다고지
# 우리말 철학사전 3
# 한 권으로 읽는 브리태니커
# 꿈의 해석
# 기술 의학 윤리
# 지눌의 선사상
# 윤리형이상학 정초
# 유교 담론의 지형학
# 역사의 연구
# 호모 노마드 유목하는 인간
# 삶은 문제해결의 연속이다
# 국문학과 민족 그리고 근대
# 청소년을 위한 서양문학사 상
# 괴델, 에셔, 바흐 상
# 문학 청년의 탄생
# 유혹의 심리학
# 중용
# 책이 있는 집 아이들이 달라졌어요
# 박수근
# 스누피의 글쓰기 완전정복
# 성경 왜곡의 역사
# 이향견문록
# 도스토예프스키, 돈을 위해 펜을 들다
# 세계종교로 보는 죽음의 의미
# 오헨리 단편선
# 열하일기 상
# 문학이 태어나는 자리
# 영국경험론연구
# 영혼에 관하여
# 비판 이론의 이념
# 박세당의 노자
# 부족해도 넉넉하다
# 21세기 지식 키워드 100
# 순간 속에 영원을 담는다
# 탐독
# 어린이와 어린이 미술
# 지식 e 3
# 꿈을 살다
# 로마가 만든 영웅들
# 명작에게 길을 묻다 1
# 다시 읽는 한국 시인
# 시 읽기의 방법
# 다윈의 플롯
# 슈퍼 자본주의
# 도교와 문학 그리고 상상력
# 간명한 중국철학사
# 고전 산문 산책
# 꽃 보고 우는 까닭
# 말들의 풍경
# 한용운 평전
# 무경계
# 존재의 미학
# 한국 문학의 사생활
# 협력과 저항
# 교수 학습 이론의 이해
# 청소년을 위한 서양문학사 하
# 옛사람들의 눈물
# 굿바이 공황장애
# 성배와 연금술
# 꿈의 세계와 파국
# 삼인삼색 미학 오디세이 세트
# 송명유학사상사
# 뇌의 충돌과 문명의 충돌
# 주제와 변주 2
# 히로시마 내 사랑
# 전국시대 비판철학
# 강호에 병이 깊어 죽림에 누웠더니
# 신화의 이미지
# 세잔의 사과
# 최고의 고전 번역을 찾아서 1
# 세상의 모든 지식
# 영어 읽기 교육론
# 평화교육탐구
# 모국어의 속살
# 철학으로 대중문화 읽기
# 한국고대의 토착신앙과 불교
# 소로의 속삭임
# 잃어버린 지혜 듣기
# 게오르그 짐멜의 모더니티 풍경 11가지
# 실천이성비판
# 보살예수
# 라프 코스터의 재미이론
# 수사학의 역사
# 너무 사랑하는 여자들
# 커튼
# 루소 학교에 가다
# 유쾌한 철학자들
# 비트겐슈타인이 살아 있다면
# 이야기 동양 신화 2
# 에릭호퍼 길위의 철학자
# 불교윤리의 현대적 이해
# 몸과 문화
# 맹자
# 한시기행
# 여성이 글을 쓴다는 것은
# 천사들의 전설
# 발터 벤야민의 모스크바 일기
# 21세기 문예이론
# 책과 함께하는 마음놀이터 1
# 동양 천문사상 인간의 역사
# 내 인생의 글쓰기
# 읽는다는 것의 역사
# 소크라테스와 헤르만 헤세의 점심
# 키치 우리들의 행복한 세계
# 학교를 찾는 아이 아이를 찾는 사회
# 탯줄코드
# 원효 철학 에세이
# 김시습 조동오위요해의 역주 연구
# 켄 윌버와 신학
# 원효
# 벽초 홍명희 평전
# 민주화 이후의 공동체 교육
# 열림과 닫힘
# 아름다운 지상의 책 한권
# 학교폭력 예방과 상담
# 진리와 방법 1
# 르네상스인 김승옥
# 도산잡영
# 철학의 에스프레소
# 철학 읽어주는 남자
# 에로스와 타나토스
# 길에서 띄우는 편지
# 미래세대와 생태윤리
# 한국운서의 이해
# 이윤기의 그리스 로마 신화 1
# 각국의 평생교육정책
# 사상의 자유의 역사
# 윤동주 평전
# 시귀의 노래
# 대장부의 삶
# 신화와 형이상학
# 한비자
# 옛이야기와 어린이문학
# 꽃들의 웃음판
# 김수영과 신동엽
# 대장장이와 연금술사
# 경험과 기억
# 만화 함석헌 세트
# 초록 덮개
# 월경하는 지식의 모험자들
# HOW TO READ 다윈
# 조광조
# 마음의 발견
# 천하관과 근대화론
# 상대주의의 두 얼굴
# 소설과 서사문화
# 임사체험 상
# 이상의 무한정원 삼차각나비
# 태초에 사랑이 있었다
# 당신에겐 철학이 있습니까?
# 예술가를 위한 형이상학
# 량치차오
# 소크라테스는 악법도 법이라고 말하지 않았다
# 도덕 교육의 이해
# 최한기의 운화와 윤리
# 나무의 죽음
# 한국의 고전 시가
# 저주의 몫
# 오늘 우리는 왜 니체를 읽는가
# 문학적 기억의 탄생
# 그리스 로마 철학자들의 삶과 죽음의 명장면
# 국제관계와 현대사회 그리고 시민교육
# 운명을 읽는 코드 열두 동물
# 창조자들
# 필로소피컬 저니
# 친일문학의 내적 논리
# 아시아의 책, 문자, 디자인
# 파우스트 그는 누구인가?
# 우리말 나들이
# 상식지존 뇌를 깨워라
# 옛 소설에 빠지다
# 성제훈의 우리말 편지 1
# 식민지 국민문학론
# 옛글에 빗대어 세상을 말하다
# 눈에 띄는 도서관 마케팅
# 프랑스 상징주의
# 욕망하는 천자문
# 프랑수아 라블레의 작품과 중세 및 르네상스의 민중문화
# 백석시의 심층적 탐구
# 지식인의 세기 2
# 이타적 인간의 출현
# 숲 속 수의사의 자연일기
# 상징과 인상
# 국민연금, 공공의 적인가 사회연대 임금인가
# 문학의영혼 음악의 영감
# 프린시피아 매네지멘타
# 우파니샤드
# 말의 미학
# 용서의 기술
# 이름 없는 하느님
# 플로티노스의 미학과 예술의 존재론적 지위
# 맑스, 탈현대적 지평을 걷다
# 현대소설의 서사주제학
# 예술, 서구를 만들다
# 실험학교 이야기
# 나르시스의 꿈
# 학교와 계급재생산
# 말라르메를 만나다
# 마음의 치유
# 그리스.로마 신화
# 뜨겁게 사랑하거나 쿨하게 떠나거나
# 한국 구비문학의 이해
# 최초의 모더니스트 정지용
# 한국 모더니즘 문학과 그 주변
# 죽음을 그리다
# 재미의 경계
# 맥루언을 읽는다
# 구리와 사무라이
# 동양적 가치의 재발견
# 벗어남으로서의 과학
# 풀어쓴 단테의 신곡
# 지식인의 세기 1
# 시장전체주의와 문명의 야만
# 사라져 가는 목소리들
# 과학의 지형도
# 창의적 발상의 원리와 기법
# 중국의 언어와 문화
# 전환기 그리스의 지식인 이소크라테스
# 칸트와 불교
# 전원시와 광시곡
# 철학사와 문학사 둘인가 하나인가
# 임사체험 하
# 지상의 아름다운 도서관
# 정말 궁금한 우리말 100가지 1
# 손오병서
# 짜라투스트라는 이렇게 말했다
# 풍류
# 함께 크는 삶의 시작
# 허세욱의 한시 특강
# 소설의 제국
# 조선후기 지식인의 대외인식
# 한국 학교조직 질적 연구
# 다석강의
# 국어 종결어미의 문법
# 학교에서 경제를 어떻게 가르칠 것인가
# 지오그래피
# 주역
# 에로스와 문명
# 한국한시와 당시의 비교
# 서정록을 찾아서
# 백제어 어휘 연구
# 권정생 이야기 2
# 공자와 천하를 논하다
# 불교학과 불교
# 백교수의 백가지 교육 이야기
# 진화론과 철학
# 디지털 시대의 문화 읽기
# 통합의 인문학
# 청색 책,갈색 책
# 교육자본론
# 신화 전사를 만들다
# 가난에 빠진 세계
# 도연명의 사상과 문학
# 아이들은 어떻게 말을 배우나
# 한국어은유 연구
# 장인
# 청소년을 위한 교양
# 이즘
# 발라시네
# 환상성
# 논어의 숲, 공자의 그늘
# 외로운 식량
# 책의 역사
# 라캉과 현대철학
# 수학교육과정과 교재연구
# 일의 발견
# 아동과 청소년의 이상심리학
# 다원주의 시대와 대안적 가치
# 몰입의 기술
# 삼인삼색미학오디세이 3
# 굶기의 예술
# 유레카 1
# 라캉의 욕망이론과 셰익스피어 텍스트 읽기
# 정보윤리 교육론
# 제3의 텍스트
# 황금가지 1
# 지식인의 두얼굴
# 교직과 교사
# 시민정부론
# 지도는 지구보다 크다
# 영미문학 영화로 읽기
# 정관정요
# 일본시가문학사
# 귀환
# 연애라는 표상
# 국어 교과서와 국가 이데올로기
# 신화 속으로 떠나는 언어여행
# 성리학, 유불도의 만남
# 그리스 비극
# 근대 영문학의 흐름
# 디지털 언어와 인문학의 변형
# 정지용 사전
# 국어경어법과 사회언어학
# 한국어 술어명사문 문법
# 게르만신화 바그너 히틀러
# 문학강의
# 고전으로 가는 길
# 라캉 : 재현과 그 불만
# 조선 중.후기 지성사 연구
# 여성문학을 넘어서
# 현상학과 해석학
# 강박성 성격장애
# 죽음 또 하나의 세계
# 막스 베버 이 사람을 보라
# 앎과 잘남
# 역주 당육전 하
# 교사는 어떻게 성장하는가
# 유아수학교육의 탐구
# 포스트구조주의의 헤겔 비판과 반비판
# 도덕 발달과 도덕 교육
# 근대중국 사상세계의 한 흐름
# 한국언어지도
# 우리말의 탄생
# 위대한 교육사상가들 7
# 논리와 심리
# 문과 노벨의 결혼
# 책 세상을 훔치다
# 영어, 내 마음의 식민주의
# 논어의 종합적 고찰
# 프랑스 철학과 문학비평
# 이혼가정 자녀 어떻게 돌볼 것인가
# 한국 마르크스학의 지평
# 비교문학의 새로운 조명
# 문학지리 한국인의 심상공간 상
# 중국 고대철학의 이해
# 토머스 핀천
# 국어 문법 연구
# 20세기 한국시인론
# 도올 김용옥 비판
# 대학.중용
# 한국 야담 연구
# 글쓰기의 기술
# 궁핍한 날의 벗
# 김준태 시인 세계문학의 거장을 만나다
# 근대 한국 종교문화의 재구성
# 고전소설 이본목록
# 럭셔리 신드롬
# 동아시아의 생사관
# 과거와 미래 사이
# 스토리텔링
# 한방음악치료학
# 세상을 보는 열일곱 개의 시선
# 법의 정신
# 니코마코스 윤리학
# 인본주의 교육사상
# 칸트와 현대 사회철학
# 한권으로 보는 사기
# 윤동주 시어사전
# 동서 종교의 만남과 그 미래
# 상호중심 독서지도
# 4월 혁명과 한국문학
# 흡혈귀의 비상
# 비트겐슈타인과 현대 철학의 언어적 전회
# 책 읽는 책
# 토마스 만 문학론
# 서울 방언의 음운론
# 교과교육학의 새로운 패러다임
# 지역문화와 디지털 콘텐츠
# 미국 흑인문학과 그 전통
# 자유로부터의 도피
# 한자 놀이
# 이익
# 창조적 존재와 초연한 인간
# 역주 당육전 중
# 아버지, 내 삶의 거울
# 고려전기 한문학사
# 신화의 땅 제주에서 토산을 만나다
# 선진유학사상의 심리학적 함의
# 트랜스 컬처를 향하여
# 스푸크
# 성배의 탐색
# 헛똑똑이의 시 읽기
# 탈식민주의를 넘어서
# 문학에서 본 만주국의 위상
# 육경과 공자인학
# 굿바이 클래식
# 내가 춤출 수 없다면 혁명이 아니다!
# 책읽기의 달인 호모 부커스
# 서양철학의 수용과 한국철학의 모색
# 개념사로서의 한국근대비평사
# 사유 급취장
# 다산문선
# 그리스 신화의 이해
# 남영신의 한국어 용법 핸드북
# 헌책방마을 헤이온와이
# 회상 꿈 그리고 사상
# 현대소설의 서사시학
# 최부 표해록 연구
# 밀란 쿤데라 소설의 기술
# 영미 희곡의 세계
# 철학을 만나면 즐겁다
# 학교 안의 미술 학교 밖의 미술
# 분논어
# 문신공방 1
# 작업실의 자코메티
# 죽음의 지대
# 임순득
# 루쉰과 저우쭈어런
# 한국어 특질론
# 국가론
# 유교의 뿌리를 찾아서
# 가르침과 배움의 철학
# 장자의 심미적 실재관
# 한국 고전여성 문학의 세계
# 우리말의 문화찾기
# 인간 컴퓨터 언어
# 사람을 그리다
# 기호로 읽는 한국 문화
# 명문가의 자식교육
# 낙천주의자 캉디드
# 말의 세상 세상의 말
# 고문진보
# 우리말글 독립운동의 발자취
# 역사상의 국가권력과 종교
# 휴머니즘론
# 다산 정약용의 편지글
# 인간등정의 발자취
# 근대 개인주의 신화
# 래디컬 에콜로지
# 시와 리얼리즘 논쟁
# 밀턴 평전
# 이상적 인간형론의 동.서비교
# 김기림의 시론과 수사학
# 엄마와 아이가 함께하는 동화 교실
# 시시포스와 그의 형제들
# 대안적 도덕교육
# 학교 평생 교육론
# 우리와 그들, 무리짓기에 대한 착각
# 클레오파트라의 바늘
# 평행과 역설
# 이름이 다른 그들의 신을 만나다
# 동물원의 탄생
# 헤겔 예나 시기 정신철학
# 즐거움의 가치사전
# 근대문학과 이태준
# 염상섭 소설어사전
# 종교성, 미래 교육의 새로운 패러다임
# 한국희곡의 근대성과 탈식민성
# 인도신화기행
# 독서치료 사례 연구
# 방법을 철학한다
# 바다의 치맛자락
# 르네상스 예술에서 괴테를 읽다
# 고향의 창조와 재발견
# 역주 매씨서평
# 인지공학심리학
# 한국 학교교육문제 연구
# 군중과 권력
# 유아를 위한 과학교육
# 현장에서 읽은 우리 소설
# 번역학 비판
# 한국 신화의 생성과 소통 원리
# 음식문화의 수수께끼
# 아프레걸 사상계를 읽다
# 나비와 전사
# 살인자들과의 인터뷰
# 공감
# 보이는 어둠
# 사회성측정
# 도덕교육의 파시즘
# 소강절의 철학
# 자연 존재론
# 조선초기 성리학과 역사학
# 조선시대 문과백서 상
# 영미문학과 디지털 문화
# 신화.꿈.신비
# 종교의 세계
# 근대 일본의 비평
# 성적 지배와 그 양식들
# 중국신화 이야기 1
# 상처 입은 용들의 노래
# 열하일기의 재발견
# 한국 중세 유교정치사상사론 1
# 율곡, 사람의 길을 말하다
# 한국 근대소설의 이념과 윤리
# 지성인을 위한 교양 브런치
# 국어교육을 위한 국어문법론
# 한국적 장르론과 장르 보편성
# 부탁해요 아인슈타인
# 계축일기
# 교사를 위한 교육학
# 들꽃학교 문학시간
# 현대 우리말의 형태론
# 인지언어학과 의미
# 숲 사람들
# 글로벌 문화이론 과정학
# 신족과 거인족의 투쟁
# 조선 성리학의 역사상
# 민족신화와 건국영웅들
# 과학의 최전선에서 인문학을 만나다
# 영국 낭만기 문학 새로읽기 1
# 문체로 읽는 소설
# 페미니즘 교육사상
# 현대철학자들
# 이황 시의 깊이와 아름다움
# 민족어의 수호와 발전
# 인문학의 수사학적 탐구
# 생각의 창과 등불
# 정보문해 INFORMATION LITERACY
# 가족의 비밀
# 누런 강 배 한 척
# 담론의 발견
# 언어 속으로
# 19세기 조선 지식인의 생각 창고
# 동물의 역습
# 비키니 입은 그리스 로마
# 철학적 산문
# 전쟁과 학교
# 범주론 명제론
# 한국 고전시가의 근대적 변전과정 연구
# 일반언어학 노트
# 사회체계이론 1
# 한국어 대우법
# 최면과 최면치료
# 일본고전소설 총론
# 현대사회윤리연구
# 일제하 유아보육사 연구
# 제1의성
# 성스러운 테러
# 한국의 웃음문화
# 한국 근대문학교육사 연구
# 제프리 초서의 문학세계
# 세상은 한 권의 책이었다
# 융 심리학과 고양이
# 일심의 철학
# 백낙청 회화록 세트
# 우리 시대의 비극론
# 미디어 교육의 이론과 실제
# 내 인생의 스승
# 한국 대하소설의 미학
# 문학@국어교육
# 몸과 사회
# 열자
# 근대중국의 지역사회와 국가권력
# 심리학
# 조선 후기 서얼문학 연구
# 한시로 읽는 우리 문학사
# 한국유학의 악론
# 정치적비평의 미래를 위하여
# 플라톤과 유럽의 전통
# 한국현대시의 실체
# 한국목간기초연구
# 셰익스피어 비평사 상
# 근대어 근대매체 근대문학
# 인물로 보는 중국현대소설의 이해
# 백범 김구선생 언론집 상
# 학파로 보는 인도사상
# 긍정적 심리학
# 고대 그리스 자연학과 도덕
# 일본 지식인과 한국
# 한문학의 연구와 해석
# 빛의 세기, 이성의 문학
# 고대영어
# 인도불교사 1
# 생명의료 윤리학
# 부자되는 땅 행복한 집 찾기
# 문화장벽을 넘어 더불어 살기
# 한글 글꼴의 역사
# 한국의 방외인문학
# 국어교육론
# 최치원의 사회사상 연구
# 향가연구
# 음운론적 변이와 변화의 상관성
# 한국 천주교의 역사사회학
# 눈의 황홀
# 디지로그 시대 책의 행방
# 한국고전시가의 전통과 계승
# 셰익스피어의 여인들 1
# 재미있는 한국어 이야기
# 몸의 역사 몸의 문화
# 교육생각
# 청시화와 조선시화의 당시론
# 우리시대의 풍수
# 의미와 진리
# 판 타데우시
# 영화 속의 청소년
# 한국 현대시인 연구
# 한국어음운론
# 초기 그리스도교의 사회사
# 한국의 교육개혁은 왜 실패하였는가?
# 중국 근세 지성의 이념과 운동
# 유교사회학의 패러다임과 사회이론
# 혁명의 문학 문학의 혁명 막심 고리끼
# 초당시와 성당시 연구
# 우리민요의 세계
# 노자
# 다사리국가론
# 도서관 정보센터의 고객만족경영
# 한.중 유서문화 개관
# 현대 한국어 통어론 연구
# 바이칼의 게세르 신화
# 스페인 황금세기 문학
# 성격심리학
# 누가 아렌트와 토크빌을 읽었다 하는가
# 에로티즘
# 20세기 미국소설의 이해 1
# 광복 후 북한현대문학 연구
# 로페 데 베가의 삶과 문학
# 진흙 천국의 시적 주술
# 한국의 언어연구
# 인간이라는 자연의 미래
# 헤겔 철학과 학문의 본질
# 세계고전 오디세이 3
# 딱딱한 사고 말랑말랑한 표현
# 초등문학교육의 담론과 아동문학의 지평
# 서양문학에 비친 동양의 사상
# 한국 한시와 여성 인식의 구도
# 발터 벤야민과 메트로폴리스
# 글 고치기 전략
# 아리스토텔레스의 인식론
# 학교체육 제 모습 찾기
# 이능화와 근대 불교학
# 종교와 일생의례
# 한국구전신화의세계
# 한국 신화의 연구
# 문화이론과 문화철학
# 누각과 정자에서 읊은 시세계
# 우리말은 서럽다
# 정보기술사회의 윤리 매뉴얼
# 고전소설과 가문의식
# 허균 문학의 실상과 전망
# 마음의 기원
# 인성교육, 성적보다 먼저다
# 의산문답
# 청소년을 위한 길가메쉬 서사시
# 보바리의 남자 오셀로의 여자
# 사로잡힌 영혼
# 철학적 수채화
# 코울리지의 시 연구
# 동심의 발견과 해방기 동시문학
# 프리즘
# 지식의 충돌
# 철학의 원리
# 한국종교연구 6
# 자아, 윤리, 그리고 철학
# 여신 미네르바의 진리파일
# 조선조 악장의 문예미학
# 영문학과 사회 비평
# 국어 문법 교과서 연구
# 한국어와 인지
# 임종국 평전
# 권력과 지성인
# 망각의 강 레테
# 생명공학과 가톨릭 윤리
# 한국 근대소설에 나타난 악의 표상 연구
# 구운몽의 통시적 연구
# 한국어와 정보화
# 인지심리학과 그 응용
# 고문진보
# 통일 인문학
# 우리 시대의 이야기꾼을 찾아서
# 책은 나름의 운명을 지닌다
# 과학은 얼마나
# 수업방법론과 교수법
# 세계의 모든 얼굴
# 101가지 철학 체험
# 한국의 교과서상
# 하이터치 문화
# 근대 논의 이후의 문학
# 한국 고소설비평 연구
# 한국개화기 시가연구
# 고전서사체 담화분석
# 탈식민과 디아스포라 문학
# 빈 비트겐슈타인 그 세기말의 풍경
# 여덟살 심리학
# 새롭게 읽는 한국의 신화
# 유학의 현대적 가용성 탐구
# 독일 고대.중세문학
# 문학의 모험
# 말구멍의 아기장수
# 언어의 예술
# 의문사 의문문의 통사와 의미
# 평신도 성전을 헐다
# 도스토예프스키 1
# 우리 고전을 찾아서
# 김운회 교수의 삼국지 바로 읽기 1
# 영미 명작 좋은 번역을 찾아서 1
# 한국신화와 스토리텔링
# 학습학
# 무위유학
# 한어문자학사
# 한국 현대시에 나타난 10대 명제
# 한국 현대시 백 년 현대 시인 백인
# 아동의 기억발달
# 최소주의의 최근 흐름
# 확실성탐구
# 비판과 포용 한국실학의 정신
# 한국 설화의 전승 양상과 소설적 변용
# 그리스.로마극의 세계
# 한글본 이언 연구
# 토머스 하디와 여성론 비평
# 재외동포작가 단편선집 15인선
# 불교와 유교
# 기호 주체 욕망
# 뇌허의 불교사상 연구
# 두공부초당시화
# 그리스 로마극의 세계 2
# 바이마르 고전주의
# 파니니문법의 규범생성모형 연구
# 여말선초 음독 입(구결)의 종합적 고찰
# 범죄신호
# 진보의 역설
# 무영진공
# 영어의 탄생
# 고악보소재 시가문학연구
# 어려운 시들
# 현대교육평가
# 경계와 소통 지역문학의 현장
# 허사 총론
# 언어지도의 미래
# 온생명과 환경, 공동체적 삶
# 한국인의 심리에 관한 보고서
# 자살의 이해와 예방
# 노자 강의
# 문학교육의 역사와 성장의 시학
# 우리 시대의 문체
# 기생충이 없었다면 섹스도 없었다
# 문학 속의 여성
# 만주문학 연구
# 전산 통사 의미론
# 서울에서 가장 거룩한 곳
# 박홍규의에드워드사이드읽기
# 우리말 살려쓰기 1
# 목록법 이론
# 한국 동화문학의 흐름과 미학
# 영남 구전자료집 1
# 김승옥과 욕망의 서사학
# 도이칠란트·도이치문학
# 임화의 문학론 연구
# 구어와 문어 자료의 실제적 연구방법론
# 영산재의 공연문화적 성격
# 메소포타미아와 히브리 신화
# 가족관계
# 경계를 넘는 새로운 글쓰기
# 세계의 서사문학과 토지
# 삼국유사의 문학적 탐구
# 들뢰즈, 카프카, 김훈
# 실재의 귀환
# 줄리아 크리스테바의 문학탐색
# 중부 동해안 방언의 성조 비교
# 동북아시아 샤머니즘과 신화론
# 세계 의회도서관
# 신없는 세계의 글쓰기
# 태평광기상절 1
# 평양지역어의 음운론
# 생략현상연구
# 세상을 바꾼 12권의 책
# 문학교육 틀짜기
# 희곡 창작의 길잡이
# 움베르토 에코 평전
# 언어 제국주의란 무엇인가
# 고대 프랑스어 통사론 연구
# 한국고전희곡의 확장
# 한국 근대 문예비평의 논리
# 중심의 옹호
# 철학이란 무엇인가
# 한국 현대소설과 섹슈얼리티
# 천금을 전하기보다 학덕을 전하라
# 국어 음운론의 해석
# 정서발달과 정서지능
# 텍스트의 유혹
# 21세기 일본문학 연구
# 우리말 문법의 양상
# 17세기 한문소설집
# 피네간의 경야
# 윤리와 준법의 리더십
# 새로운 인문주의자는 경계를 넘어라
# 탐서주의자의 책
# 또래관계
# 문학체험연구
# 김광균연구
# 경제학의 핵심 지식정보원
# WHITHER MORPHOLOGY IN THE NEW MILLENIUM
# 역주 흠흠신서 3
# 참교육자 마리아 몬테소리
# 19세기 서울의 사랑
# 인류의 역사를 뒤바꾼 위대한 생각들
# 한국어의 시제 서법 동작상
# 돌봄과 치유의 철학
# 조선조 유학자의 중용읽기
# 플라톤
# 감금의 정치
# 승려와 철학자
# 문학의 공간
# 정말 궁금한 우리 예절 53가지
# 우리말에 대한 예의
# 통합적 상담
# 생태문학
# 기계비평
# 학문, 묻고 답하다
# 인간 딜레마
# 어른들을 위한 창의학 수업
# 문학치료의 이론적 기초
# 사랑의 문화사
# 악마의 문화사
# 오해의 심리학
# 만해 한용운 평전
# 바깥에서
# 탈식민주의! 저항에서 유희로
# 말이 올라야 나라가 오른다 2
# 전기
# 몽테뉴의 숲에서 거닐다
# 실업계 얌순이들의 보고서
# 놀이로 이해하는 우리 아이처음 만나는 놀이치료
# 대지에서 인간으로 산다는 것
# 동아시아 건국 신화의 역사와 논리
# 다윈안의 신
# 종교의 자연사
# 그리스인이 들려주는 그리스 신화
# 요람 속의 과학자
# 표상하기와 개입하기
# 교육정책의 탐구논리
# 한국계몽주의 문학사론
# 한국인의 죽음관
# 아부의 즐거움
# 침묵의 종교 유교
# 알타이 이야기
# 옛집의 향기 나무
# 철학적 사유와 진리에 대하여 1
# 라틴아메리카 신화의 전설
# 개인적 지식
# 소크라테스의 대화록
# 주서백선
# 깨어진 거울의 눈
# 얘들아 산책가자
# 언어의 죽음
# 인지심리학
# 장애청소년 전환교육
# 한국인류학 백년
# 중국 당대 신시사
# 교육에 관한 철학적 담론
# 한국의 근대와 교육
# 시가사와 예술사의 관련양상 2
# 역과 탈현대의 논리
# 러시아 문학사
# 모더니즘
# 감각의 박물학
# 번역은 반역인가
# 공부의 즐거움
# 도쿄대생은 바보가 되었는가
# 지식 e 2
# 서기 1000년의 세계
# 누구를 위한 종교인가
# 제2의 성 상
# 여성의 정체성 어떤 여성이 될 것인가
# 풍경의 발견
# 가족, 사적 소유, 국가의 기원
# 몽테뉴와 파스칼
# 음악적 아름다움에 대하여
# 욕망과 지혜의 문화사전 몸
# 죽어가는 자의 고독
# 책
# 책벌레들의 동서고금 종횡무진
# 교양 모든 것의 시작
# 시선은 권력이다
# 암호 이야기
# 나는 고발한다
# 라인홀드 니버
# 상상계의 인류학적 구조들
# 연암에게 글쓰기를 배우다
# 유혹하는 글쓰기
# 내 인생의 탐나는 심리학 50
# 그림으로 읽는 생생 심리학
# 프로이트, 영혼의 해방을 위하여
# 환상적인 가족 만들기
# 정신분석학의 근본 개념
# 정신분석 강의
# 따귀 맞은 영혼
# 사랑의 기술
# 윌리엄 제임스 교육론
# 한국전통문화와 유아교육
# 학습이론
# 국가과외
# 해석학과 교육
# 유아를 위한 자연친화교육
# 초등학교문화 이해
# 다문화시대 박물관교육
# 한국대학행정
# 창의성 교육
# 위기의 학교
# 다산의 논어해석연구
# 천년의 철학
# 세계사적 역사인식과 칸트의 영구평화론
# 로크의 정치 철학
# 성리학의 형이상학 도론
# 자연주의
# 사랑과 사상의 거리 재기
# 사람 잡는 정체성
# 아인슈타인
# 소나무와 나비
# 과학과 종교 사이에서
# 방법서설
# 사유란 무엇인가
# 에우튀데모스
# 공산당 선언
# 향연
# 조선의 유학
# 원효의 대승철학
# 주자학의 길
# 국역 신간소왕사기
# 정약용의 철학
# 유교 아시아의 힘
# 양화소록
# 장자
# 한국 한문학의 사상적 지평
# 유교
# 정선 목민심서
# 워더링 하이츠
# 향가문학의 이론과 해석
# 농사꾼 아이들의 노래
# 리얼리즘의 시 정신과 시 교육
# 이상소설의 해석
# 소설의 곡예사
# 한국고전비평사
# 고려 한시 연구
# 한국문학논저 유형별총목록 5
# 문학과 방언
# 사찰 누정 그리고 한시
# 20세기 한국시의 표정
# 한국 현대시의 인지시학적 이해
# 김수영 시의 수사학
# 동아시아 문학과 여성
# 그레이엄 그린의 소설
# 북한의 문예체론
# 조선의 여배우들
# 차세대 문학의 이해
# 타자들, 에움길에 서다
# 원전확정과 작가론의 반성
# 북한의 문예정책과 구비문학의 활용
# 북한문학사
# 한일고대문학비교연구
# 구비문학 연구의 길찾기
# 바로잡은 무정
# 김소행의 글쓰기 방식과 삼한습유
# 대명률직해의 국어학적 연구
# 디킨즈와 신분과 자본
# 중국소설 연구의 지평을 넓히는 만남
# 연행록 연구총서 세트
# 경상도 우리 탯말
# 영미 명작 좋은 번역을 찾아서 2
# 조선후기 대도설화 연구
# 나의문학 이야기
# 간찰
# 우리말 방언 성조의 비교
# 기본생활한자
# 고대국어 어휘 표기 한자의 자별 용례 연구
# 토박이말 이름의 실태와 분석
# 바른말 고운말 2
# 경북 방언의 연구
# 한국어 대화 화제와 말차례 체계
# 이숭녕 현대국어학의 개척자
# 한국어 어휘형성론
# 조선어어휘편람
# 김성동 천자문
# 국어 실력이 밥 먹여준다 2
# 우리말 연구의 이론과 실제
# 한국어발음사전
# 문학으로 여는 종교
# 한국 교회음악 수용사
# 이동휘와 기독교
# 종교문화의 논리
# 미국종교사
# 보로부두르
# 이윤기의 그리스 로마 신화 2
# 다른 사람들의 신화
# 이윤기의 그리스 로마 신화 3
# 작가 연구 방법론
# 한국어 발음 교육
# 당신은 아들에게 어떤 아버지 입니까
# 그리스 로마 신화
# 도덕은 무엇으로부터 오는가
# 인문으로 읽는 주역
# 인간은 왜 낚시를 하는가
# 여성 철학자
# 이야기된 자기
# 고사성어 대사전
# 단숨에 읽는 세계문학
# 프로이트와 비유럽인
# 한국의 아들과 아버지
# 이병주의 동서양 고전탐사 1
# 탈 형이상학적 사유
# 어린이 문학을 보는 시각
# 감정과 에로스의 철학
# 알코올과 예술가
# 문학 속의 파시즘
# 일상고통 걷어차기
# 금강삼매경론 상
# 아첨론
# 포스트모던의 조건
# 실재계 사막으로의 환대
# 현대철학의 거장들
# 18세기 한국한시사 연구
# 유아 예절교육
# 보르헤스의 지팡이
# 노인상담
# 진리의 본질에 관하여
# 일본 다이쇼문학사
# 20년 만의 특강 철학이란 무엇입니까
# 읽기 교육의 이론과 실제
# 의례 1
# 산해경
# 고전문학기행
# 부모교육
# 토머스 쿤
# 미운 오리 새끼
# 채연이의 일기 1
# 최근 미국소설론과 작품세계
# 문학 속의 서울
# 대한민국 대표 브랜드 한글
# 페미니즘 과학교육이란 무엇인가
# 일본 쇼와문학사
# 동아시아 역사교과서는 어떻게 쓰여 있을까?
# 민족, 문화, 인간 인류학의 창조
# 흰 그늘의 미학을 찾아서
# 기호, 상징, 신화
# 담론분석의 이론과 실제
# 싸이코 짱가의 영화 속 심리학
# 카뮈를 위한 변명
# 부모교육
# 교육방법 및 교육공학
# 동양의 미학
# 예술철학
# 다시 실학이란 무엇인가
# 국어 어원학 통사
# 후설의 현상학과 현대 철학
# 도교의 신과 신선 이야기
# 러시아민담연구
# 그림 한자
# 세계의 종교
# 나의 삶을 바꾼 공황과 공포
# 우리 아이들에게 역사를 어떻게 가르칠 것인가
# 영혼의 해부
# 해체주의와 그 이후
# 당시선
# 백야의 뻬쩨르부르그에서 2
# 독도견문록
# 남자들의 거짓말 사전
# 당시
# 처음 읽는 우파니샤드
# 교사의 권리 학생의 인권
# 고통에게 따지다
# 생명윤리의 철학
# 아리스토텔레스의 시학 연구
# 한시 읽기의 즐거움
# 20세기 국한문체의 형성과정
# 사유의 공간
# 주체와 욕망
# 노자와 신화
# 수학의 철학
# 다카하시 도루의 조선유학사
# 호메로스의 세계
# 김나지움 논리학입문
# 하이데거와 나치즘
# 존재자와 본질에 대하여
# 일본 메이지문학사
# 다산 정약용
# 평민열전
# 서사양식과 담론의 근대성
# 우리말 철학사전 1
# 기학의 모험 1
# 목적의 왕국
# 카뮈 1
# 책사냥꾼
# 시를 읽는 즐거움
# 권위와 개인
# 춘추전국시대의 법치사상과 세.술
# 연행록 연구
# 언어 컴퓨터 코퍼스 언어학
# 학교 따돌림의 지도와 상담
# 나타샤 스토리
# 국어교육의 재개념화와 문학교육
# 예수 노자를 만나다
# 세계화와 자아 정체성
# 이조 후기 한시의 사회사
# 과학 인문학 그리고 대학
# 특수아동의 심리학적 이해
# 논리학 진리란 무엇인가
# 경전으로 본 세계종교
# 책에 취해 놀다
# 문제중심학습의 이론과 실제
# 인간의 얼굴을 가진 지식
# 논쟁과 담론
# 동양종교와 서양사상
# 예문으로 익히는 우리말 어휘
# 함북 북부지역어 연구
# 동양신화 백과사전
# 없이 계신 하느님, 덜 없는 인간
# 앙리 메쇼닉과 현대비평
# 조선시대의 내단사상
# 김주환
# 문학으로 보는 성
# 지상의 낯선 자 보들레르
# 일본 지식인의 사상
# 다윈은 어떻게 프로이트에게 낚시를 가르쳤는가
# 퇴계 이황 아들에게 편지를 쓰다
# 포월과 소내의 미학
# 에드워드 사이드 다시 읽기
# 완역 두보율시
# 살아있는 우리말의 역사
# 독일의 역사교육
# 말로
# 고전 다시 읽기 1
# 민담 상징 무의식
# 그리스인들의 신화와 사유
# 욕망의 힘
# 유교사상의 본질과 현재성
# 동서 철학의 교섭과 동서양 사유 방식의 차이
# 와신상담의 마음으로 일본을 기록하다
# 시각예술교육에서 평가란 무엇인가?
# 붓끝으로 부사산 바람을 가르다
# 동서양의 하모니를 위한 창의학
# 다산 사서경학 연구
# 사이버 문화와 예술의 유혹
# 다빈치 코드와 숨겨진 역사
# 한국 근대소설사의 시각
# 도스또예프스끼 읽기사전
# 현대시와 판타지
# 독백의 철학에서 대화의 철학으로
# 들풀들이 들려주는 위대한 백성이야기 3
# 과학으로 기독교 새로 보기
# 호락논쟁 형성과 전개
# 유학경림 1
# 덕윤리의 비판적 조명
# 한국어의 의성어와 의태어
# 도교와 그리스도교
# 금옥총부
# 철학대사전
# 현대시 동인의 시세계
# 윤동주 시 깊이 읽기
# T.S. 엘리엇 비평
# 꿈꾸는 과학
# 포크너
# 세계의 영웅신화
# 문체론
# 교육법과 교육기본권
# 신세대 명심보감
# 목릉문단과 석주 권필
# 일본문학 번역 60년 현황과 분석
# 희망의 근거
# 구한말 교육구국운동 연구
# 고대 그리스 법제사
# 퇴옹성철의 깨달음과 수행
# 아렌트와 하이데거
# 공자의 군자학
# 요가 전통
# 비평, 90년대 문학을 묻다
# 김석범 화산도 읽기
# 옥스퍼드 영문학사
# 중국문자학
# 한국의 지명
# 전통미술 문화교육
# 편지로 쓴 철학사 탈레스에서 헤겔까지
# 성리학의 형이상학 시론
# 라틴 아메리카의 문학과 사회
# 돈키호테, 열린 소설
# 위진현학
# 비도 눈도 내리지 않는 시나가와역
# 8가지 커뮤니케이션 기법
# 레지오 에밀리아 접근법
# 담화분석
# 종교와 예술
# 이광수 문학사전
# 안씨가훈
# 나의 국토 나의 산하 1
# 셰익스피어 평전
# 조선시대의 열녀 담론
# 프랑스 현대시
# 지역공동체와 평생교육
# 근대를 넘어서려는 모험들
# 인지행동 놀이치료
# 정치이론과 정치철학
# 작은인간
# 신여성, 길 위에 서다
# 현명하게 세속적인 삶
# 프랑켄슈타인의 글쓰기
# 팝콘먹는 소크라테스
# 한국고전문학의 교육적 성찰
# 한국문학사의 논리와 체계
# 츙렬쇼오의
# 디지털 시대의 서사와 매체
# 중세국어 연결어미와 보조사의 통합형
# 영남 방언 성조 비교
# 데리다의 정신분석학 해체
# 나정암과 이퇴계의 철학사상
# 장재
# 한시 미학과 역사적 진실
# 장소의 탄생
# 천재와 광기
# 세계화의 철학적 담론
# 갑골문 자전을 겸한 갑골문해독
# 작가생산의 사회사
# 세속의 성전
# 안면도가 우리 학교야
# 이광수와 문화의 기획
# 조선의 영혼을 훔친 노래들
# 동아시아 근대사상론
# 아방가르드는 없다
# 춘추
# 근대 계몽기 시가 자료집 1
# 불온한 문화, 프랑스 시인을 찾아서
# 죽은 시인들의 사회
# 슐라이어마허의 해석학
# 인도 바로보기
# 역사가 새겨진 우리말 이야기
# 언어와 언어학의 이해
# 지능심리학
# 공간의 기호학
# 순자론
# 대중문학과 정전에 대한 반역
# 시의 희생자 김수영
# 서동과 처용이 삼국유사를 박차고 나오다
# 구성주의와 읽기 쓰기
# 설화와 역사
# 디지로그 스토리텔링
# 귀납논리와 과학철학
# 록음악의 미학
# 근대계몽기의 학술 문예사상
# 문화연구와 인문학의 미래
# 한국어 문법론
# 물리주의
# 한국근대문학과 일본
# 한국 모더니즘 시사
# 중국고전문학이론
# 주자학을 위한 변명
# 한국 고전시가의 정체성
# 문학교수의 베스트셀러 산책
# 교육인류학
# 기정진
# 문학에서 문화로
# 미로의 구조
# 방법론의 문제와 원시종교
# 교육개혁의 환상
# 도산서원
# 조선 후기 유림의 사상과 활동
# 러시아 문학의 이해
# 박경리와 토지
# 상식의 힘
# 인물로 보는 한국의 불교 사상
# 시간 밖의 문명
# 노장철학
# 이승만
# 한국고전용어사전
# 탈식민의 텍스트 저항과 해방의 담론
# 욕망과 형식의 시학
# 동양의 도덕교육 사상
# 고전문학연구의 쟁점적 과제와 전망 상
# 악장가사연구
# 국어학연구 50년
# 근대전환기 동아시아 삼국과 한국
# 합리성의 새로운 지평
# 동아시아 비판 사상의 뿌리
# 신라 원효의 금강삼매경론 연구
# 감성의 파문
# 역대 한국문법의 통합적 연구
# 우리 한문학사의 해외체험
# 생명에서 종교로
# 영국소설사
# 과학의 도전 철학의 응전
# 법적 논증의 기초
# 중국철학사상사
# 한국 고전
# 마리아 몬테소리 자서전
# 황금책갈피
# 옛사람 옛노래 향가와 속요
# 중국철학산책
# 괴테와 다산 통하다
# 신뢰도
# 국어 대우법 체계의 정보화 연구
# 도덕성 발달이론과 교육
# 대화의 철학
# 조선조 성리철학의 구조적 탐구
# 식민지 근대성과 소설의 양식
# 중국당대문학사
# 글로벌 시대의 문학
# 문자문학에서 전자문화로
# 국어방언문법
# 인지언어학의 이해
# 문법과 텍스트
# 역학서 연구
# 질병의 사회심리학
# 구성주의와 학습의 사회이론
# 물질 정신 창조
# 듀이
# 희랍문학사
# 동양의 고대 커뮤니케이션 사상
# 한국어 형용사 어휘문법
# 한국출판의 이해
# 공자 속의 붓다 붓다 속의 공자
# 정신건강과 정신분석
# 어떻게 가르칠 것인가
# 왕양명의 생명철학
# 풀어 옮긴 조선유학사
# 세계의 시문학
# 소설 연구의 첫걸음
# 졸수재집 1
# 강용흘 그의 삶과 문학
# 한국어 용언부정문의 역사적 변화
# 글쓰기와 발표하기
# 마음의 철학
# 대학장구비지
# 정이
# 최한기의 철학과 사상
# 유교 민주주의 왜 & 어떻게
# 이상시 작품론
# 우리말 속담사전
# 유진의 학교
# 부모교육
# 장자가 노자를 이야기한다
# 오규원의 시의 현대성
# 삼한습유
# 시와 진실
# 팀 기반 학습
# 법철학의 문제들
# 화서학파의 철학과 시대의식
# 다시 읽는 존 밀턴의 실낙원
# 재미한인문학연구
# 한국 실학의 새로운 모색
# 길을 묻는 철학자
# 프랑스어 문학과 현대성의 인식
# 문학의 미래
# 팽팽한 밧줄 위에서 느린 춤을
# 일반이성문법
# 행복한 십대 만들기 10가지
# 살아있는 특수교육이야기
# 한국어 경어법, 힘과 거리의 미학
# 원효의 정토사상 연구
# 소설적 주체 그 탄생과 전변
# 20세기 한국문학과 근대성의 변증법
# 경판방각소설 판본 연구
# 한국 고전시가 문학의 분석과 탐색
# 백제 전설 여행
# 한국어 화용표지 연구
# 1960년대 소설의 근대성과 주체
# 황해도방언연구
# 제임스의 미완성 세계
# 위대한 도서관 사상가들
# 책으로 세상을 꿈꾸다
# 스토킹의 심리학
# 당대소설연구
# 조선후기 시가와 여성
# 고사기
# T.S.엘리엇 시
# 삶을 바꾸는 설화의 힘 설화의 재발견
# 유아교육학 탐구
# 처용설화의 해석학
# 조선조 유학자의 지향과 갈등
# 고대 러시아문학의 시학
# 동북아 샤머니즘 문화
# 국역 백곡집
# 한국초등교육사
# 유가사상과 중국식 사회주의 철학
# 침묵과 소리의 극작가 사무엘 베케트
# 도이치문학 용어사전
# 한국 근대문학의 몇 가지 주제
# 쉽게 읽는 용비어천가 2
# 형식의 운명 운명의 형식
# 한국의 독서문화사
# 워커홀리즘
# 한국어 학습자 말뭉치와 오류 분석
# 숲께 드리는 숲의 철학
# 보살핌의 현상학
# 한국 현대시와 전통
# 설화와 상상력
# 국어 음운 현상의 공시성과 통시성
# 형태론과 음운론
# 영미문학을 읽는 새로운 패러다임
# 이강수 교수의 노장철학이해
# 예기집설대전 2
# 일본불교사 근대
# 신춘문예의 문단사적 연구
# 고전문학과 여성화자 그 글쓰기의 전략
# 한국 고전장편소설의 형성 과정
# 이야기 한국고전문학사
# 의학은 나의 아내, 문학은 나의 애인
# 뼈꽃이 피다
# 언어 습득의 이론과 실상
# 국제지적재산권법
# 창조적 영혼을 위한 영상 글쓰기
# 유가의 심성론과 현대 심리철학
# 주대의 상제의식과 유학사상
# 옛노래 옛사람들의 내면풍경
# 재만조선인 친일문학 작품집
# 한국 고전소설사의 거점
# 국어사 연구 어디까지 와 있는가
# 한국어 통사구조론
# 창의성 개발을 위한 디자인교육 콘텐츠
# 프로테스탄트 교회의 역사와 신학
# 서울의 시 서울의 시인들
# 개인관계의 사회심리학
# 수학교육학 기초론
# 지평 확대의 철학
# 현상학과 유식론
# 정선의 아라리
# 한국 민족예악과 시가문학
# 허웅 선생의 우리말 연구
# 교육정책의 나비효과를 꿈꾸며
# 한국 민중시 문학사
# 류성룡선생 시문학연구
# J.M. 쿳시의 대화적 소설
# 교통심리학
# 교육과정과 평가의 쟁점
# 철학연구 50년
# 한국철학의 쟁점
# 인터넷 통신 언어의 이해
# 아
# 칸트의 인간관과 인식존재론
# 한국유교의 현실인식과 변혁론
# 존 밀턴의 문학과 사상
# 조명희와 선봉
# 문학과 게임의 상상력
# 서정 민요 그리고 몇 편의 다른 시
# 중국 명시 감상
# 훈민정음의 사람들
# 파라다이스
# 신라 향가 연구
# 향찰 연구 12제
# 마침법 씨끝의 융합과 그 한계
# 생활속의 심리이야기
# 철학과 인문학의 대화
# 새 천년의 한국문화 다른 것이 아름답다
# 칸트 그리고 헤겔
# 한국 한문학 연구의 새 지평
# 현대사회와 구비문학
# 동아시아의 문화와 문학 1
# 한국 패설문학 연구
# 한국현대작가와 불교
# 사람이 꽃 보다 아름다운 이유
# 통사론 이해
# 페미니즘 언어학의 이해
# 시간과 공간을 조각하다
# 교육사회학
# 주경(主敬)의 철학자 동춘당 송준길
# 미국 소수민족 문학의 이해
# 문학으로 돌아가다
# 여성작가와 문학적 글쓰기
# 체호프 드라마의 웃음세계
# 김정식 작품 연구
# 동시대의 삶과 서사 교육
# 신운의 전통과 변용
# 교육 선진화를 꿈꾸며
# 다산 정약용의 토지개혁사상
# 삼국지 통속연의
# 사에구사 교수의 한국문학 연구
# 한국 문인의 전향 연구
# 개혁개방과 중국조선족 소설문학
# 고전문학 담당층과 문학의식의 제 문제
# 신화 제의 문학
# 현대우리말의 반어법연구
# 청구야담
# 동아시아 지식사회와 문화 커뮤니케이션
# 한국 제4기학 연구
# ICT 활용 영어교육
# 철학의 센세이션
# 시인은 숲을 지킨다
# 한국고전문학과 세계인식
# 현대중국 단절과 연속
# 셰익스피어와 후기 구조주의
# 19세기 영국 소설과 영화
# 중앙어의 음운론적 변이양상
# 15세기 국어통어론
# 국어 문법의 교육과 연구
# 디지털 텍스트와 문화읽기
# 타자의 서사학
# 이야기 일본 문학사
# 한국 시문학의 빈터를 찾아서
# 구비문학과 인접학문
# 탈근대와 영문학
# 한국문학을 위한 담론
# 설화 연구 방법의 통일성과 다양성
# 중국문학유람
# 국어문법의 이해 1
# 중국 시학의 이해
# 고전소설의 창작 기법 연구
# 지식인의 자기 발견
# 통합 정보활용교육과정론
# 종교철학 에세이
# 한국한시대관 1
# 1970년대의 유신체제를 넘는 민족문학론
# 소설과 우연의 질서
# 퇴계시 색인
# 한국 고전시가의 내면미학
# 한국고소설의 창작방법 연구
# 문학 속의 인문학
# 한국어 구어연구 2
# 영미시와 한국시 2
# 한국 현대시의 전통과 불교적 시학
# 출판연구와 출판평설
# 알타이의 자연과 문화
# 현대이론과 신인문학
# 한국문화와 가족치료
# 평생교육의 이해
# 논리와 탐구
# 현대철학은 진리를 어떻게 정의하는가
# 일본문학과 종교
# 중국근대 문학사상 연구
# 필립 라킨의 시
# 국어문법의 이해 2
# 중세조선어 문체 연구
# 훈민정음 연구
# 국어의 단어형성과 의미해석
# 사회언어학적 조사와 연구방법
# 남북한 중등 도덕교과서 비교
# 제2언어로서의 한국어 교육의 이해와 탐색
# 한국교육 그러나 희망은 있다
# 학교단위책임경영제
# 변하고 있는 미국 교육
# 한국 근대시의 출발과 지향
# 금향졍긔
# 하이너 뮐러 문학의 이해
# 국문학 연구와 문헌학
# 단가집성
# 한국현대소설과 서사전략
# 생성의 시학
# 아리랑 시원설 연구
# 토니 모리슨
# 현대문학사와 민족이라는 이념
# 사실주의 소설의 재인식
# 조선 지식인의 문학과 현실인식
# 한 수필가의 우리 옛문학 읽기
# 외국인의 한국어 연구
# 우리말 연구와 문법 교육의 역사
# 예술의 기호 기호의 예술
# 불우한, 불후의 노래
# 한국여인의 발자취
# 보육시설 운영관리
# 전통교육의 현대적 이해
# 아주 쉽고도 재미있는 철학이야기
# 이을호전서
# 문학 연구와 정치적 변화
# 중국현대문학의 근대성 재인식
# 한국문학의 직관과 상황 그리고 표현기술
# 홍루몽보
# 호손과 역사의 시학
# 중국문학의 전통과 모색
# 관형격조사 '의'의 통어적 의미 분석
# 어휘 통사론
# 한 일 양어 수 분류사의 명사 부류화 기능에 관한 대조적 연구
# 백범김구의 정치사상
# 예이츠 시선
# 국가 윤리 교육론
# 충렬협의젼
# 컴퓨터 정보처리를 위한 생략언어의 현시
# 가곡원류
# 지역문학과 주변부적 시각
# 근대 서술의 형성
# 시인은 숲으로 가지 못한다
# 경기도 사투리 연구
# 역학서와 국어사 연구
# 우리 말본과 인지
# 우리말 음운 연구의 실제
# 사회언어학
# 한국 중세 토지제도사
# 외래어 이렇게 다듬어 쓰자
# 재미의 비즈니스
# 왼손과 오른손
# 바람이 흙이 가르쳐 주네
# 고문헌의 조직과 정보활용
# 한국교원행정
# 홍대용
# 관념론 미학 비판
# 쇼펜하우어 인생론
# 가족로망스와 성장소설
# 현대시와 장르 비평
# 경계의 시 읽기
# 시가사와 예술사의 관련 양상
# 미적 근대성과 한국문학사
# 호르바트의 새로운 민중극 연구
# 헤르만 헤세와 동양의 지혜
# 한국 한시의 분석과 시각
# 고대한국어연구
# 한 중 호칭어의 대조 연구
# 20세기 신학사상 1
# 대학이 변하고 있다
# 지식과 사고
# 한국 도교문화의 초점
# 재생연전 상
# 재생연전 하
# 후쿠옹자전
# 한국 현대시의 근대성과 탈식민성
# 최소주의의 새로운 이해
# 국어사와 한자음
# 테크놀로지와 함께 하는 수학교육
# 법률해석의 한계
# 짜라두짜는 이렇게 말했지
# 속수 사고전서 한글색인집
# 의식혁명
# 상식속의 철학 상식밖의 철학
# 루카치 미학사상
# 신논리학
# 이야기 속의 논리학
# 백서 노자
# 세종대왕의 정치철학
# 오영수 문학연구
# 한국 전후 문제시인 연구 1
# 빠블로 네루다
# 조선어어휘편람
# 의미구조와 통사구조 그리고 그 너머
# 동국사영연구
# 신화의 힘

# %% [markdown]
# ### 소설

# %%
for i in range(1,62):
    url = "https://book.naver.com/category/index.naver?cate_code=100&tab=recommend&list_type=list&sort_type=salecount&page={}".format(i)
    res = requests.get(url)
    res.raise_for_status()
    soup = BeautifulSoup(res.text, "lxml") #우리가 가져온 html 문서를 -> 뷰티풀숲 객체로 만든다.

    books = soup.find_all("a", attrs={"class":"N=a:bta.title"})
    
   
    for book in books:
        book_url = book["href"]
        book_res=requests.get(book_url)
        try:
            book_res.raise_for_status()

            soup2 = BeautifulSoup(book_res.text, "lxml")

            criticism = soup2.find("li", attrs={"class":"d_tab2"})
            if criticism:
                criticism_url = 'https://book.naver.com' + str(criticism.a['href'])
                criticism_res = requests.get(criticism_url)
                criticism_res.raise_for_status()

                soup3 = BeautifulSoup(criticism_res.text, "lxml")

                pcriticism = soup3.find("div", attrs={"id":"pubReviewContent"})
                review = pcriticism.p.get_text()
                #print(f"출판사서평: {review}")
                criticism_list.append(review)
                #print()
            else:
                personreview = soup2.find("div", attrs={"id":"bookIntroContent"})
                if personreview:
                    ppreview = personreview.get_text()
                    #print(f"책소개: {ppreview}")
                    criticism_list.append(ppreview)
                    #print()
                else:
                    #print("서평없음")
                    criticism_list.append("X")
        except:
            continue

# %%
for i in range(1,62):
    url = "https://book.naver.com/category/index.naver?cate_code=100&tab=recommend&list_type=list&sort_type=salecount&page={}".format(i)
    res = requests.get(url)
    res.raise_for_status()
    soup = BeautifulSoup(res.text, "lxml") #우리가 가져온 html 문서를 -> 뷰티풀숲 객체로 만든다.

    books = soup.find_all("a", attrs={"class":"N=a:bta.title"})

    for book in books:
        title = book.get_text()
        #print(title)
        title_list.append(title)

# %%
final=list(zip(title_list, criticism_list))
print(final)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
import pandas

df = pandas.DataFrame(final)
df.head()
# Out:
#                       0                                                  1
# 0  사랑하라 한번도 상처받지 않은 것처럼   시집 <그대가 곁에 있어도 나는 그대가 그립다> <외눈박이 물고기의 사랑>의 저자...
# 1                  마음사전  수만 가지의 빛깔을 지닌 ‘마음’에 관한 ‘사전’─희로애락애오욕 300낱말이 마음의...
# 2             입 속의 검은 잎  '문학과지성 시인선' 80권, 기형도 시집. 처음이자 마지막이 된 이 시집에서 기형...
# 3                행복의 정복  활발한 사회활동을 펼친 20세기의 지성으로 유명한 러셀이 쓴 단 한 권의 행복론. ...
# 4                  백범일지  본격적인 원전비평으로 정본화에 완벽을 기한 『백범일지』 \r 일반적으로 역사적 문헌...

# %%
df.to_csv("naver_book_책정보.csv", encoding='utf-8-sig', index=False)
